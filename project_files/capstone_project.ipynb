# %% [markdown]
# <h1>Capstone Project</h1>

# %% [markdown]
# <p>This is a notebook for my Coursera Applied Data Science Capstone Project</p>

# %% [markdown]
# <h2>Objective</h2>

# %% [markdown]
# <p>Gathering valuable information and insights on car accidents in Seattle. Then using this information to create a machine learning model that is capable of predicting the severity of traffic accidents based on certain attributes.</p>

# %% [markdown]
# <font size="+1"><b>Importing Libraries</b></font>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2>Load the Data</h2>

# %%
df = pd.read_csv(r'Data-Collisions.csv')
# Out:
# C:\Users\fredr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# <h2>Data Exploration and Cleaning</h2>

# %%
pd.set_option("max_columns", 50)
df.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  \
# 0  Matched  Intersection  37475.0
# 1  Matched         Block      NaN
# 2  Matched         Block      NaN
# 3  Matched         Block      NaN
# 4  Matched  Intersection  34387.0
#
#                                       LOCATION EXCEPTRSNCODE EXCEPTRSNDESC  \
# 0                   5TH AVE NE AND NE 103RD ST                         NaN
# 1   AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N           NaN           NaN
# ...

# %% [markdown]
#  <font size="+1"><b>Rows and Columns</b></font>

# %%
df.shape
# Out:
# (194673, 38)

# %% [markdown]
# <p><b>The data set contains 38 columns (severitycode is duplicated) and 194673 rows.</b></p>

# %% [markdown]
#  <font size="+1"><b>Timeframe</b></font>

# %%
df.sort_values(by='INCDTTM')[['INCDTTM', 'INCDATE']].head()
# Out:
#         INCDTTM                 INCDATE
# 7996   1/1/2004  2004/01/01 00:00:00+00
# 10714  1/1/2004  2004/01/01 00:00:00+00
# 5083   1/1/2004  2004/01/01 00:00:00+00
# 3291   1/1/2004  2004/01/01 00:00:00+00
# 5940   1/1/2004  2004/01/01 00:00:00+00

# %% [markdown]
# <b>From 1/1/2004</b>

# %%
df.sort_values(by='INCDTTM', ascending=False)[['INCDTTM', 'INCDATE']].head()
# Out:
#                     INCDTTM                 INCDATE
# 192339  9/9/2019 9:27:00 AM  2019/09/09 00:00:00+00
# 191820  9/9/2019 9:10:00 PM  2019/09/09 00:00:00+00
# 191832  9/9/2019 9:08:00 AM  2019/09/09 00:00:00+00
# 192599  9/9/2019 9:06:00 AM  2019/09/09 00:00:00+00
# 190713  9/9/2019 8:45:00 AM  2019/09/09 00:00:00+00

# %% [markdown]
# <b>to 9/9/2019</b>

# %% [markdown]
# <h3>Data Types</h3>

# %%
df.dtypes
# Out:
# SEVERITYCODE        int64
# X                 float64
# Y                 float64
# OBJECTID            int64
# INCKEY              int64
# COLDETKEY           int64
# REPORTNO           object
# STATUS             object
# ADDRTYPE           object
# INTKEY            float64
# LOCATION           object
# EXCEPTRSNCODE      object
# EXCEPTRSNDESC      object
# SEVERITYCODE.1      int64
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT         int64
# PEDCOUNT            int64
# PEDCYLCOUNT         int64
# VEHCOUNT            int64
# INCDATE            object
# INCDTTM            object
# JUNCTIONTYPE       object
# SDOT_COLCODE        int64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# PEDROWNOTGRNT      object
# SDOTCOLNUM        float64
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# ...

# %% [markdown]
# <h4>Cast to datetime</h4>

# %% [markdown]
# <b>The type of the INCDATE and INCDTTM needs to be cast to datetime, and we only need one of the two column.</b>

# %%
df = df.astype({'INCDTTM': 'datetime64'})
df.drop(['INCDATE'], axis=1, inplace=True)
df.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  \
# 0  Matched  Intersection  37475.0
# 1  Matched         Block      NaN
# 2  Matched         Block      NaN
# 3  Matched         Block      NaN
# 4  Matched  Intersection  34387.0
#
#                                       LOCATION EXCEPTRSNCODE EXCEPTRSNDESC  \
# 0                   5TH AVE NE AND NE 103RD ST                         NaN
# 1   AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N           NaN           NaN
# ...

# %% [markdown]
# <h3>Removing obvious columns</h3>

# %% [markdown]
# <b>X and Y columns contains the coordinates for the incident. We can drop these, though we will be using the LOCATION column for the location of the accident.</b>

# %%
df.drop(['X', 'Y'], axis=1, inplace=True)
df.head(1)
# Out:
#    SEVERITYCODE  OBJECTID  INCKEY  COLDETKEY REPORTNO   STATUS      ADDRTYPE  \
# 0             2         1    1307       1307  3502005  Matched  Intersection
#
#     INTKEY                    LOCATION EXCEPTRSNCODE EXCEPTRSNDESC  \
# 0  37475.0  5TH AVE NE AND NE 103RD ST                         NaN
#
#    SEVERITYCODE.1      SEVERITYDESC COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  \
# 0               2  Injury Collision        Angles            2         0
#
#    PEDCYLCOUNT  VEHCOUNT             INCDTTM  \
# 0            0         2 2013-03-27 14:54:00
#
#                              JUNCTIONTYPE  SDOT_COLCODE  \
# 0  At Intersection (intersection related)            11
#
#                                         SDOT_COLDESC INATTENTIONIND UNDERINFL  \
# 0  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN         N
#
#     WEATHER ROADCOND LIGHTCOND PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# ...

# %% [markdown]
# <b>There's no information on the EXCEPTRSNCODE and EXCEPTRSNDESC columns in the metadata.</b>

# %%
df.drop(['EXCEPTRSNCODE', 'EXCEPTRSNDESC'], axis=1, inplace=True)
df.head(1)
# Out:
#    SEVERITYCODE  OBJECTID  INCKEY  COLDETKEY REPORTNO   STATUS      ADDRTYPE  \
# 0             2         1    1307       1307  3502005  Matched  Intersection
#
#     INTKEY                    LOCATION  SEVERITYCODE.1      SEVERITYDESC  \
# 0  37475.0  5TH AVE NE AND NE 103RD ST               2  Injury Collision
#
#   COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0        Angles            2         0            0         2
#
#               INCDTTM                            JUNCTIONTYPE  SDOT_COLCODE  \
# 0 2013-03-27 14:54:00  At Intersection (intersection related)            11
#
#                                         SDOT_COLDESC INATTENTIONIND UNDERINFL  \
# 0  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN         N
#
#     WEATHER ROADCOND LIGHTCOND PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0  Overcast      Wet  Daylight           NaN         NaN      NaN         10
#
# ...

# %% [markdown]
# <b>The INTKEY column contains the key that corresponds to the intersection associated with a collision. Since ADDRTYPE displays the type of address (alley, block or intersection) and LOCATION specifies the location, we can drop the INTKEY columns<b>

# %%
df.drop(['INTKEY'], axis=1, inplace=True)
df.head(1)
# Out:
#    SEVERITYCODE  OBJECTID  INCKEY  COLDETKEY REPORTNO   STATUS      ADDRTYPE  \
# 0             2         1    1307       1307  3502005  Matched  Intersection
#
#                      LOCATION  SEVERITYCODE.1      SEVERITYDESC COLLISIONTYPE  \
# 0  5TH AVE NE AND NE 103RD ST               2  Injury Collision        Angles
#
#    PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT             INCDTTM  \
# 0            2         0            0         2 2013-03-27 14:54:00
#
#                              JUNCTIONTYPE  SDOT_COLCODE  \
# 0  At Intersection (intersection related)            11
#
#                                         SDOT_COLDESC INATTENTIONIND UNDERINFL  \
# 0  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN         N
#
#     WEATHER ROADCOND LIGHTCOND PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0  Overcast      Wet  Daylight           NaN         NaN      NaN         10
#
#           ST_COLDESC  SEGLANEKEY  CROSSWALKKEY HITPARKEDCAR
# ...

# %% [markdown]
# <h3>Missing Values</h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 37 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEVERITYCODE    194673 non-null  int64
#  1   X               189339 non-null  float64
#  2   Y               189339 non-null  float64
#  3   OBJECTID        194673 non-null  int64
#  4   INCKEY          194673 non-null  int64
#  5   COLDETKEY       194673 non-null  int64
#  6   REPORTNO        194673 non-null  object
#  7   STATUS          194673 non-null  object
#  8   ADDRTYPE        192747 non-null  object
#  9   INTKEY          65070 non-null   float64
#  10  LOCATION        191996 non-null  object
#  11  EXCEPTRSNCODE   84811 non-null   object
#  12  EXCEPTRSNDESC   5638 non-null    object
#  13  SEVERITYCODE.1  194673 non-null  int64
#  14  SEVERITYDESC    194673 non-null  object
#  15  COLLISIONTYPE   189769 non-null  object
# ...

# %% [markdown]
# <b>There are clearly a lot of missing values in several of the columns</b>

# %%
df.isnull().sum()
# Out:
# SEVERITYCODE           0
# X                   5334
# Y                   5334
# OBJECTID               0
# INCKEY                 0
# COLDETKEY              0
# REPORTNO               0
# STATUS                 0
# ADDRTYPE            1926
# INTKEY            129603
# LOCATION            2677
# EXCEPTRSNCODE     109862
# EXCEPTRSNDESC     189035
# SEVERITYCODE.1         0
# SEVERITYDESC           0
# COLLISIONTYPE       4904
# PERSONCOUNT            0
# PEDCOUNT               0
# PEDCYLCOUNT            0
# VEHCOUNT               0
# INCDTTM                0
# JUNCTIONTYPE        6329
# SDOT_COLCODE           0
# SDOT_COLDESC           0
# INATTENTIONIND    164868
# UNDERINFL           4884
# WEATHER             5081
# ROADCOND            5012
# LIGHTCOND           5170
# PEDROWNOTGRNT     190006
# SDOTCOLNUM         79737
# SPEEDING          185340
# ST_COLCODE            18
# ST_COLDESC          4904
# SEGLANEKEY             0
# CROSSWALKKEY           0
# HITPARKEDCAR           0
# ...

# %% [markdown]
# <b>Columns containig missing values</b>

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['X', 'Y', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE',
#        'EXCEPTRSNDESC', 'COLLISIONTYPE', 'JUNCTIONTYPE', 'INATTENTIONIND',
#        'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND', 'PEDROWNOTGRNT',
#        'SDOTCOLNUM', 'SPEEDING', 'ST_COLCODE', 'ST_COLDESC'],
#       dtype='object')

# %% [markdown]
# <h4>Handling Missing values</h4>

# %% [markdown]
# <b>Dropping column which won't be used in the further analysis:</b>

# %% [markdown]
# <font size="+1"><b>Descriptive analysis</b></font>

# %%
df.describe()
# Out:
#         SEVERITYCODE              X              Y       OBJECTID  \
# count  194673.000000  189339.000000  189339.000000  194673.000000
# mean        1.298901    -122.330518      47.619543  108479.364930
# std         0.457778       0.029976       0.056157   62649.722558
# min         1.000000    -122.419091      47.495573       1.000000
# 25%         1.000000    -122.348673      47.575956   54267.000000
# 50%         1.000000    -122.330224      47.615369  106912.000000
# 75%         2.000000    -122.311937      47.663664  162272.000000
# max         2.000000    -122.238949      47.734142  219547.000000
#
#               INCKEY      COLDETKEY         INTKEY  SEVERITYCODE.1  \
# count  194673.000000  194673.000000   65070.000000   194673.000000
# mean   141091.456350  141298.811381   37558.450576        1.298901
# std     86634.402737   86986.542110   51745.990273        0.457778
# min      1001.000000    1001.000000   23807.000000        1.000000
# ...

# %%
df.describe(include=['O'])
# Out:
#        REPORTNO   STATUS ADDRTYPE  \
# count    194673   194673   192747
# unique   194670        2        3
# top     1782439  Matched    Block
# freq          2   189786   126926
#
#                                                  LOCATION EXCEPTRSNCODE  \
# count                                              191996         84811
# unique                                              24102             2
# top     BATTERY ST TUNNEL NB BETWEEN ALASKAN WY VI NB ...
# freq                                                  276         79173
#
#                                             EXCEPTRSNDESC  \
# count                                                5638
# unique                                                  1
# top     Not Enough Information, or Insufficient Locati...
# freq                                                 5638
#
#                           SEVERITYDESC COLLISIONTYPE                 INCDATE  \
# ...

# %% [markdown]
# <p><b>From the count we can see that there are many columns with missing data.</b></p>
